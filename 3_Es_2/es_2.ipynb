# %%
import pandas as pd
from collections import Counter
import string
import nltk
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2', device="cuda")

nltk.download('wordnet')
nltk.download('punkt')

csv=pd.read_csv('data\\TLN-definitions-24.csv')[:14]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\danie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\danie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stop = stopwords.words('english')
char_rem = list(set("#$%'()*+,./:;<=>?[\]^_`{|}~" + "“" + "”"))
definizioni_full=pd.read_csv('data\\TLN-definitions-24.csv')
definizioni_full=definizioni_full.drop('Annotator', axis=1)
definizioni_full=definizioni_full.dropna()
definizioni=definizioni_full.map(lambda x: word_tokenize(str(x).lower()))
definizioni=definizioni.map(lambda x: [item for item in x if(item not in stop and item not in char_rem)])
definizioni['pen'] = definizioni['pen'].apply(lambda x: [item for item in x if item != "pen"])
definizioni['cigarette'] = definizioni['cigarette'].apply(lambda x: [item for item in x if item != "cigarette"])
definizioni['cloud'] = definizioni['cloud'].apply(lambda x: [item for item in x if item != "cloud"])
definizioni['ontology'] = definizioni['ontology'].apply(lambda x: [item for item in x if item != "ontology"])
display(definizioni)

definitions = []
definitions.append([definition.replace("pen", "") for definition in csv["pen"].astype(str).tolist()])
definitions.append([definition.replace("cigarette", "") for definition in csv["cigarette"].astype(str).tolist()])
definitions.append([definition.replace("cloud", "") for definition in csv["cloud"].astype(str).tolist()])
definitions.append([definition.replace("ontology", "") for definition in csv["ontology"].astype(str).tolist()])

definitions_full=[]
definitions_full.append([definizioni_full.replace("pen", "") for definizioni_full in csv["pen"].astype(str).tolist()])
definitions_full.append([definizioni_full.replace("cigarette", "") for definizioni_full in csv["cigarette"].astype(str).tolist()])
definitions_full.append([definizioni_full.replace("cloud", "") for definizioni_full in csv["cloud"].astype(str).tolist()])
definitions_full.append([definizioni_full.replace("ontology", "") for definizioni_full in csv["ontology"].astype(str).tolist()])
# Out:
#                                                   pen  \
# 0           [object, used, write, paper, filled, ink]
# 1                        [object, used, write, paper]
# 2              [tool, used, write, paper, using, ink]
# 3                          [object, used, write, ink]
# 4   [object, used, write, papers, usually, tool, p...
# 5       [stick, write, ink, word, sketches, drawings]
# 6                   [object, used, write, paper, ink]
# 8                         [writing, tool, using, ink]
# 9   [tool, writing, paper, usually, black, blue, red]
# 10              [object, used, writing, sheet, paper]
# 11  [object, used, writing, could, different, colo...
# 12                          [tool, used, write, text]
# 14  [object, tool, used, people, primarily, write,...
#
#                                             cigarette  \
# 0   [object, filled, mainly, bu, tobacco, smoked, ...
# 1                  [cylinder, paper, tobacco, inside]
# 2                          [object, smoked, pleasure]
# 3          [object, contains, tobacco, used, smoking]
# 4   [product, made, tobacco, inserted, paper, coul...
# 5   [consumable, stick, light, order, inhalate, 's...
# 6                         [cylinder, tobacco, inside]
# 8   [cigarete, tabacco, wrapped, paper, used, smok...
# 9                      [tool, allows, smoke, tobacco]
# 10  [consumable, light, order, aspire, 's, smoke, ...
# 11  [object, used, inhale, nicotine, combustion, t...
# 12  [product, made, tabacco, filter, wrapped, pape...
# 14  [cilindrical, object, made, paper, treated, to...
#
#                                                 cloud  \
# 0                           [atmospheric, phenomenon]
# 1                   [specific, atmosphere, condition]
# 2             [white, sky, object, responsible, rain]
# 3   [mass, water, drops, atmosphere, witch, take, ...
# 4   [formations, sky, derived, condensation, water...
# 5   [abstraction, set, services, delivered, internet]
# 6                  [isa, cluster, tiny, water, drops]
# 8   [system, computer, accessible, different, user...
# 9              [term, refers, system, remote, server]
# 10  [collection, interconnected, computers, capabl...
# 11  [word, could, different, senses, like, 1, mete...
# 12  [system, used, access, services, provided, rem...
# 14  [natural, sense, gaseous, amount, water, suspe...
#
#                                              ontology
# 0   [philosophical, study, nature, structure, bein...
# 1     [field, philosophy, used, universal, universal]
# 2   [tool, used, create, common, knowledge, differ...
# 3                      [method, represent, knowledge]
# 4   [science, study, carachteristics, related, exi...
# 5                  [study, formal, definition, sense]
# 6                                [branch, phylosophy]
# 8   [knowledge, structure, used, store, relationsh...
# 9                                [branch, philosophy]
# 10                          [something, always, true]
# 11  [philosophical, concept, used, formalize, logi...
# 12                   [method, used, store, knouledge]
# 14  [structure, based, concepts, relationships, ba...

# %%
# Pulisce una definizione rimuovendo parole poco significative, la punteggiatura e restituisce una lista di parole chiave.
def clean_definition(definition):
   
    stopwords = set(nltk.corpus.stopwords.words('english'))
    words = nltk.word_tokenize(definition.lower())
    filtered_words = [word for word in words if word.isalnum() and word not in stopwords and word not in string.punctuation]
    return filtered_words

#  Trova i termini più frequenti nelle definizioni fornite e il loro conteggio.
def get_top_k_terms(definitions, top_k):
    
    lemmatizer = WordNetLemmatizer()
    all_words = []
    
    for definition in definitions:
        all_words.extend(definition)
    
    counter = Counter(all_words)
    top_k_terms = counter.most_common(top_k)
    
    genus_terms_with_freq = [(lemmatizer.lemmatize(term), freq) for term, freq in top_k_terms]
    return genus_terms_with_freq

# Calcola la somiglianza del bag of words tra un synset e una lista di termini.
def bag_of_words_similarity(synset, definitions,term_freq):

    synset_words_set = set(synset)
    definitions_words_set = set(definitions)
    
    common_words = synset_words_set & definitions_words_set
    similarity = sum(term_freq[word] for word in common_words if word in term_freq)
    #print(len(common_words))
    return len(common_words)

def semantic_similarity(synset_definition, definitions ,term_freq):

    embeddings1 = model.encode([synset_definition])
    embeddings2 = model.encode(definitions)

    similarities = np.dot(embeddings1, np.transpose(embeddings2))
    similarity = np.max(similarities)
    
    return similarity

    


    
# Trova il synset di WordNet più appropriato per un gruppo di definizioni, usando i termini genus.
def find_best_synset(definitions, genus_terms_with_freq, depth, use_transformer):
    term_freq_dict = {term: freq for term, freq in genus_terms_with_freq}
    best_synset = None
    best_similarity = 0

    def recursive_find_synset(synset, current_depth):
        nonlocal best_synset, best_similarity
        if current_depth > depth:
            return
        
        hyponyms = synset.hyponyms()
        if not hyponyms:
            return
        
        for hyponym in hyponyms:

            if(use_transformer):
                def_words = hyponym.definition()
                similarity = semantic_similarity(def_words, definitions, term_freq_dict)
            else:
                def_words = clean_definition(hyponym.definition())
                similarity = bag_of_words_similarity(def_words, definitions, term_freq_dict)

            if similarity > best_similarity:
                best_similarity = similarity
                best_synset = hyponym
            
            recursive_find_synset(hyponym, current_depth + 1)

    for term, freq in genus_terms_with_freq:
        synsets = wn.synsets(term)
        for synset in synsets:
            recursive_find_synset(synset, 1)
    
    return best_synset


# Restituisce dalla lista delle definizioni di un concetto le parole che si ripetono più di una volta.
def get_frequent_terms(definitions):
    
    all_words = []
    for definition in definitions:
        all_words.extend(definition)
    
    counter = Counter(all_words)
    frequent_terms = [word for word, freq in counter.items() if freq > 1]
    return frequent_terms


# Filtrare definizioni che contengono meno di 4 parole
for i in range(len(definitions)):
    definitions[i] = list(filter(lambda s: len(s.split()) > 4, definitions[i]))   

cleaned_definitions = []
for def_group in definitions:
    cleaned_definitions.append([clean_definition(defn) for defn in def_group])
print(cleaned_definitions)

top_k = 6
depth = 4

# Processare ogni gruppo di definizioni
for i, def_group in enumerate(cleaned_definitions):
    genus_terms_with_freq = get_top_k_terms(def_group, top_k)
    frequent_terms = get_frequent_terms(def_group)
    print(i)
    try:
        best_synset = find_best_synset(frequent_terms, genus_terms_with_freq,depth,False)
        
        best_synset_st = find_best_synset(definitions_full[i], genus_terms_with_freq,depth,True)
        if best_synset:
            print(f"Concept {i + 1}: Best Synset - {best_synset.name()} - {best_synset.definition()}")
        else:
            raise ValueError("No suitable synset found")
        
        if best_synset_st:
            print(f"Concept ST {i + 1}: Best Synset - {best_synset_st.name()} - {best_synset_st.definition()}")
        else:
            raise ValueError("No suitable synset found")
    except Exception as e:
        print(f"Concept {i + 1}: Error - {str(e)}")
    
    print(f"Top {len(genus_terms_with_freq)} terms with frequencies: {genus_terms_with_freq}")
# Out:
# [[['object', 'used', 'write', 'paper', 'filled', 'ink'], ['object', 'used', 'write', 'paper'], ['tool', 'used', 'write', 'paper', 'using', 'ink'], ['object', 'used', 'write', 'ink'], ['object', 'used', 'write', 'papers', 'usually', 'tool', 'permit', 'spread', 'ink', 'paper', 'following', 'direction', 'hand', 'utilizer', 'stylographic', 'case', 'required', 'manually', 'inked', 'ball', 'case', 'ink', 'flowing', 'body', 'ball', 'rolls', 'paper'], ['stick', 'write', 'ink', 'word', 'sketches', 'drawings'], ['object', 'used', 'write', 'paper', 'ink'], ['tool', 'used', 'write', 'text'], ['writing', 'tool', 'using', 'ink'], ['tool', 'writing', 'paper', 'usually', 'black', 'blue', 'red'], ['object', 'used', 'writing', 'sheet', 'paper'], ['object', 'used', 'writing', 'could', 'different', 'colour', 'shape'], ['tool', 'used', 'write', 'text'], ['cylindrical', 'object', 'used', 'represent', 'generic', 'concept', 'piece', 'paper']], [['object', 'filled', 'mainly', 'bu', 'tobacco', 'smoked', 'pleasure'], ['cylinder', 'paper', 'tobacco', 'inside'], ['object', 'smoked', 'pleasure'], ['object', 'contains', 'tobacco', 'used', 'smoking'], ['product', 'made', 'tobacco', 'inserted', 'paper', 'could', 'made', 'industrially', 'using', 'papers', 'contain', 'filter', 'usually', 'made', 'cotton', 'light', 'smoked', 'user', 'get', 'sensation', 'pleasure', 'inhalation', 'nicotine'], ['consumable', 'stick', 'light', 'order', 'inhalate', 'smoke', 'usually', 'filled', 'nicotine'], ['cylinder', 'tobacco', 'inside'], ['cigarete', 'tabacco', 'wrapped', 'paper', 'used', 'smoking'], ['cigarete', 'tabacco', 'wrapped', 'paper', 'used', 'smoking'], ['tool', 'allows', 'smoke', 'tobacco'], ['consumable', 'light', 'order', 'aspire', 'smoke', 'usualy', 'filled', 'nicotine'], ['object', 'used', 'inhale', 'nicotine', 'combustion', 'tobacco'], ['product', 'made', 'tabacco', 'filter', 'wrapped', 'paper', 'smoked', 'personal', 'pleasure', 'cause', 'health', 'problems'], ['wrapped', 'piece', 'paper', 'contains', 'mainly', 'tabacco', 'chemical', 'substances']], [['specific', 'atmosphere', 'condition'], ['white', 'sky', 'object', 'responsible', 'rain'], ['mass', 'water', 'drops', 'atmosphere', 'witch', 'take', 'different', 'form', 'produce', 'meteorological', 'phenomenom', 'rain', 'snow', 'hail', 'storm'], ['formations', 'sky', 'derived', 'condensation', 'water', 'particles', 'atmosphere', 'white', 'black', 'usually', 'signals', 'possibility', 'imminent', 'rain'], ['abstraction', 'set', 'services', 'delivered', 'internet'], ['isa', 'cluster', 'tiny', 'water', 'drops'], ['system', 'computer', 'accessible', 'different', 'users', 'different', 'places'], ['term', 'refers', 'system', 'remote', 'server'], ['cloud', 'collection', 'interconnected', 'computers', 'capable', 'storing', 'data', 'specific', 'format', 'making', 'accessible', 'one', 'users'], ['cloud', 'word', 'could', 'different', 'senses', 'like', '1', 'meteorological', 'phenomenon', '2', 'computer', 'science', 'means', 'set', 'online', 'services', 'customers', 'buy', 'providers'], ['system', 'used', 'access', 'services', 'provided', 'remote', 'servers']], [['philosophical', 'study', 'nature', 'structure', 'beings', 'reality', 'categories', 'relationship'], ['field', 'philosophy', 'used', 'universal', 'universal'], ['tool', 'used', 'create', 'common', 'knowledge', 'different', 'communicating', 'agents'], ['method', 'represent', 'knowledge'], ['science', 'study', 'carachteristics', 'related', 'existence', 'philosophical', 'concept', 'often', 'studied', 'metaphysics', 'concept', 'exploited', 'several', 'domains', 'medicine'], ['study', 'formal', 'definition', 'sense'], ['branch', 'phylosophy'], ['knowledge', 'structure', 'used', 'store', 'relationships', 'entities'], ['ontology', 'branch', 'philosophy'], ['something', 'always', 'true'], ['philosophical', 'concept', 'used', 'formalize', 'logical', 'way', 'object', 'observed', 'word'], ['method', 'used', 'store', 'knouledge']]]
# 0
# Concept 1: Best Synset - writing_paper.n.01 - paper material made into thin sheets that are sized to take ink; used for writing correspondence and manuscripts
# Concept ST 1: Best Synset - sheet.n.02 - paper used for writing or printing
# Top 8 terms with frequencies: [('used', 11), ('write', 9), ('paper', 9), ('object', 8), ('ink', 8), ('tool', 6), ('writing', 4), ('using', 2)]
# 1
# Concept 2: Best Synset - cigarette.n.01 - finely ground tobacco wrapped in paper; for smoking
# Concept ST 2: Best Synset - cigarillo.n.01 - small cigar or cigarette wrapped in tobacco instead of paper
# Top 8 terms with frequencies: [('tobacco', 7), ('paper', 6), ('object', 4), ('smoked', 4), ('pleasure', 4), ('used', 4), ('made', 4), ('nicotine', 4)]
# 2
# Concept 3: Best Synset - fog.n.02 - an atmosphere in which visibility is reduced because of a cloud of some substance
# Concept ST 3: Best Synset - genius_loci.n.01 - the special atmosphere of a place
# Top 8 terms with frequencies: [('different', 4), ('atmosphere', 3), ('rain', 3), ('water', 3), ('service', 3), ('system', 3), ('specific', 2), ('white', 2)]
# 3
# Concept 4: Best Synset - biotechnology.n.02 - the branch of engineering science in which biological science is used to study the relation between workers and their environments
# Concept ST 4: Best Synset - ontology.n.02 - the metaphysical study of the nature of being and existence
# Top 8 terms with frequencies: [('used', 5), ('philosophical', 3), ('study', 3), ('knowledge', 3), ('concept', 3), ('structure', 2), ('philosophy', 2), ('universal', 2)]
